# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/317.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.3 MB 1.3 MB/s eta 0:04:08
#      ---------------------------------------- 0.3/317.3 MB 4.9 MB/s eta 0:01:06
#      ---------------------------------------- 0.9/317.3 MB 7.9 MB/s eta 0:00:40
#      ---------------------------------------- 1.4/317.3 MB 8.9 MB/s eta 0:00:36
#      ---------------------------------------- 1.9/317.3 MB 9.5 MB/s eta 0:00:34
#      --------------------------------------- 2.5/317.3 MB 10.0 MB/s eta 0:00:32
#      --------------------------------------- 3.0/317.3 MB 10.2 MB/s eta 0:00:31
#      --------------------------------------- 3.6/317.3 MB 10.5 MB/s eta 0:00:30
#       -------------------------------------- 4.2/317.3 MB 10.6 MB/s eta 0:00:30
#       -------------------------------------- 4.7/317.3 MB 10.7 MB/s eta 0:00:30
#       -------------------------------------- 5.3/317.3 MB 10.8 MB/s eta 0:00:29
# ...

# %%
from pyspark.context import SparkContext

# %%
spark = SparkContext.getOrCreate()

# %%
mirdd1= spark.textFile('Base_Train_Transf.csv')

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os

# %%
df= pd.read_csv('C:/Users/renzo/Base_Train_Transf.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df= pd.read_csv('C:/Users/renzo/Base_Train_Transf.csv', sep=';',index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df
# Out:
#          PERIODO_1       LLAVE  TARGET  ANTIGUEDAD  ANTIGUEDAD_rootInv  \
# 0           202401  E-44004501       0         262            0.061780
# 1           202310  E-44330401       0          19            0.229416
# 2           202309  E-42434991       0          54            0.136083
# 3           202310  E-71987203       1         115            0.093250
# 4           202310  E-43290482       0         245            0.063888
# ...            ...         ...     ...         ...                 ...
# 2914667     202312  E-08773535       0          48            0.144338
# 2914668     202312  E-15759458       0          29            0.185695
# 2914669     202312  E-41793902       1          92            0.104257
# 2914670     202312  E-43338354       0          91            0.104828
# 2914671     202312  E-70551590       0          28            0.188982
#
#          CUOTA_TOPE_power2  Deuda_PE_BF_rootInv  Deuda_PE_SF_U1A_rootInv  \
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# PERIODO_1                            int64
# LLAVE                               object
# TARGET                               int64
# ANTIGUEDAD                           int64
# ANTIGUEDAD_rootInv                 float64
# CUOTA_TOPE_power2                  float64
# Deuda_PE_BF_rootInv                float64
# Deuda_PE_SF_U1A_rootInv            float64
# Deuda_PE_SF_U6M                    float64
# Deuda_PE_SF_U6M_rootInv            float64
# Deuda_TC_PE_BF                     float64
# Deuda_TC_PE_BF_log                 float64
# Deuda_TC_PE_SF_log                 float64
# Deuda_TC_SF_U3M                    float64
# DISPONIBLE_FINAL_SC_RED            float64
# DISPONIBLE_FINAL_SC_RED_log        float64
# DISPONIBLE_FINAL_SC_RED_rootInv    float64
# EDAD                                 int64
# LINEACREDITO_rootInv               float64
# montodesembolsoPE_rootInv          float64
# MONTOSOLES_onTHEM                  float64
# MONTOSOLES_onTHEM_rootInv          float64
# ...

# %%
import missingno as msno
=msno.bar(df)
# Out:
# <Axes: >

# %%
X=df
#X=X.drop(['TARGET'],axis=1,inplace=True)
X
#Y=df["TARGET"]
# Out:
#          PERIODO_1  ANTIGUEDAD  ANTIGUEDAD_rootInv  CUOTA_TOPE_power2  \
# 0           202401         262            0.061780       1.212289e+06
# 1           202310          19            0.229416       3.894134e+05
# 2           202309          54            0.136083       3.788551e+06
# 3           202310         115            0.093250       1.336267e+06
# 4           202310         245            0.063888       8.575316e+05
# ...            ...         ...                 ...                ...
# 2914667     202312          48            0.144338       2.471467e+06
# 2914668     202312          29            0.185695       3.783357e+05
# 2914669     202312          92            0.104257       2.225766e+04
# 2914670     202312          91            0.104828       6.431078e+05
# 2914671     202312          28            0.188982       8.684562e+05
#
#          Deuda_PE_BF_rootInv  Deuda_PE_SF_U1A_rootInv  Deuda_PE_SF_U6M  \
# ...

# %%
Y
# Out:
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
#           ..
# 2914667    0
# 2914668    0
# 2914669    1
# 2914670    0
# 2914671    0
# Name: TARGET, Length: 2914672, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.93
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96    552252
#            1       0.34      0.37      0.35     30683
#
#     accuracy                           0.93    582935
#    macro avg       0.65      0.66      0.66    582935
# weighted avg       0.93      0.93      0.93    582935

# %%
plt.figure(figsize=(20, 10))
tree.plot_tree(model, feature_names=X.columns, class_names=True, filled=True)
plt.show()

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/124.9 MB 4.9 MB/s eta 0:00:26
#    ---------------------------------------- 0.9/124.9 MB 7.7 MB/s eta 0:00:17
#    ---------------------------------------- 1.4/124.9 MB 8.9 MB/s eta 0:00:14
#     --------------------------------------- 2.0/124.9 MB 9.6 MB/s eta 0:00:13
#     --------------------------------------- 2.5/124.9 MB 10.1 MB/s eta 0:00:13
#     --------------------------------------- 3.1/124.9 MB 9.8 MB/s eta 0:00:13
#    - -------------------------------------- 3.6/124.9 MB 10.5 MB/s eta 0:00:12
#    - -------------------------------------- 4.2/124.9 MB 10.7 MB/s eta 0:00:12
#    - -------------------------------------- 4.8/124.9 MB 10.8 MB/s eta 0:00:12
#    - -------------------------------------- 5.3/124.9 MB 10.6 MB/s eta 0:00:12
# ...

# %%
df
# Out:
#          PERIODO_1  ANTIGUEDAD  ANTIGUEDAD_rootInv  CUOTA_TOPE_power2  \
# 0           202401         262            0.061780       1.212289e+06
# 1           202310          19            0.229416       3.894134e+05
# 2           202309          54            0.136083       3.788551e+06
# 3           202310         115            0.093250       1.336267e+06
# 4           202310         245            0.063888       8.575316e+05
# ...            ...         ...                 ...                ...
# 2914667     202312          48            0.144338       2.471467e+06
# 2914668     202312          29            0.185695       3.783357e+05
# 2914669     202312          92            0.104257       2.225766e+04
# 2914670     202312          91            0.104828       6.431078e+05
# 2914671     202312          28            0.188982       8.684562e+05
#
#          Deuda_PE_BF_rootInv  Deuda_PE_SF_U1A_rootInv  Deuda_PE_SF_U6M  \
# ...

# %%
df= pd.read_csv('C:/Users/renzo/Base_Train_Transf.csv', sep=';')

# %%
df
# Out:
#          Unnamed: 0  PERIODO_1       LLAVE  TARGET  ANTIGUEDAD  \
# 0                 0     202401  E-44004501       0         262
# 1                 1     202310  E-44330401       0          19
# 2                 2     202309  E-42434991       0          54
# 3                 3     202310  E-71987203       1         115
# 4                 4     202310  E-43290482       0         245
# ...             ...        ...         ...     ...         ...
# 2914667     2914667     202312  E-08773535       0          48
# 2914668     2914668     202312  E-15759458       0          29
# 2914669     2914669     202312  E-41793902       1          92
# 2914670     2914670     202312  E-43338354       0          91
# 2914671     2914671     202312  E-70551590       0          28
#
#          ANTIGUEDAD_rootInv  CUOTA_TOPE_power2  Deuda_PE_BF_rootInv  \
# 0                  0.061780       1.212289e+06             0.000000
# 1                  0.229416       3.894134e+05             0.000000
# ...

# %%
X=df.drop(['Unnamed: 0','LLAVE','TARGET'],axis=1)
y=df['TARGET']

# %%
X
# Out:
#          PERIODO_1  ANTIGUEDAD  ANTIGUEDAD_rootInv  CUOTA_TOPE_power2  \
# 0           202401         262            0.061780       1.212289e+06
# 1           202310          19            0.229416       3.894134e+05
# 2           202309          54            0.136083       3.788551e+06
# 3           202310         115            0.093250       1.336267e+06
# 4           202310         245            0.063888       8.575316e+05
# ...            ...         ...                 ...                ...
# 2914667     202312          48            0.144338       2.471467e+06
# 2914668     202312          29            0.185695       3.783357e+05
# 2914669     202312          92            0.104257       2.225766e+04
# 2914670     202312          91            0.104828       6.431078e+05
# 2914671     202312          28            0.188982       8.684562e+05
#
#          Deuda_PE_BF_rootInv  Deuda_PE_SF_U1A_rootInv  Deuda_PE_SF_U6M  \
# ...

# %%
Y
# Out:
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
#           ..
# 2914667    0
# 2914668    0
# 2914669    1
# 2914670    0
# 2914671    0
# Name: TARGET, Length: 2914672, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#Crear las matrices DMatrix para el conjunto de entrenamiento y prueba
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
#Configuración de los parámetros del modelo
params = {
    'objective': 'binary:logistic',  # Tipo de problema (binario en este caso)
    'max_depth': 6,                  # Profundidad máxima de los árboles
    'eta': 0.3,                      # Tasa de aprendizaje
    'eval_metric': 'logloss',        # Métrica de evaluación
    'seed': 42                       # Semilla para reproducibilidad
}

# %%
#Entrenar el modelo
num_rounds = 100  # Número de rondas (épocas)
model = xgb.train(params, dtrain, num_rounds)

# %%
#solo usar cuando es una matriz 
y_pred = model.predict(X_test)

#Para XGBClassifier se requiere redondear los resultados si es un problema binario
y_pred = [1 if y > 0.5 else 0 for y in y_pred]  # Si estás usando clasificación

#Calcular la precisión y otras métricas
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')

#Matriz de confusión y reporte de clasificación
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))

print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 y_pred = model.predict(X_test)
#       3 #Para XGBClassifier se requiere redondear los resultados si es un problema binario
#       4 y_pred = [1 if y > 0.5 else 0 for y in y_pred]  # Si estás usando clasificación
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:2356, in Booster.predict(self, data, output_margin, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    2275 """Predict with data.  The full model will be used unless `iteration_range` is
#    2276 specified, meaning user have to either slice the model or use the
#    2277 ``best_iteration`` attribute to get prediction from best model returned from
#    (...)
#    2353
#    2354 """
#    2355 if not isinstance(data, DMatrix):
# ...

# %%
import xgboost as xgb

#Crear la DMatrix para entrenamiento y prueba
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

#Configurar los parámetros del modelo
params = {
    'objective': 'binary:logistic',
    'max_depth': 6,
    'eta': 0.3,
    'eval_metric': 'logloss',
    'seed': 42
}

#Número de rondas (épocas) para el entrenamiento
num_rounds = 100

#Entrenar el modelo
model = xgb.train(params, dtrain, num_rounds)

# %%
#Calcular la precisión y otras métricas
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')

#Matriz de confusión y reporte de clasificación
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))

print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9290
# Confusion Matrix:
# [[530354  21898]
#  [ 19476  11207]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96    552252
#            1       0.34      0.37      0.35     30683
#
#     accuracy                           0.93    582935
#    macro avg       0.65      0.66      0.66    582935
# weighted avg       0.93      0.93      0.93    582935

# %%
from xgboost import XGBClassifier

#Crear el modelo XGBClassifier
model = XGBClassifier(
    objective='binary:logistic',
    max_depth=6,
    learning_rate=0.3,
    n_estimators=100,
    random_state=42
)

#Entrenar el modelo
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
#solo usar cuando es una matriz 
y_pred = model.predict(X_test)

#Para XGBClassifier se requiere redondear los resultados si es un problema binario
y_pred = [1 if y > 0.5 else 0 for y in y_pred]  # Si estás usando clasificación

#Calcular la precisión y otras métricas
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')

#Matriz de confusión y reporte de clasificación
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))

print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9496
# Confusion Matrix:
# [[549915   2337]
#  [ 27053   3630]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97    552252
#            1       0.61      0.12      0.20     30683
#
#     accuracy                           0.95    582935
#    macro avg       0.78      0.56      0.59    582935
# weighted avg       0.93      0.95      0.93    582935

# %%
pip install lightgbm
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.4 MB 3.1 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.4 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 9.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Crear los datos de LightGBM
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# Configuración del modelo LightGBM
params = {
    'objective': 'binary',        # Para clasificación binaria; usa 'multiclass' para múltiples clases
    'metric': 'binary_logloss',   # Métrica para problemas de clasificación binaria
    'boosting_type': 'gbdt',      # Gradient Boosting Decision Tree (GBDT)
    'learning_rate': 0.1,         # Tasa de aprendizaje
    'num_leaves': 31,             # Número de hojas en un árbol; ajusta para controlar el overfitting
    'max_depth': -1,              # Profundidad máxima del árbol (-1 para sin límite)
    'n_estimators': 100           # Número de árboles en el modelo
}

# Entrenar el modelo
model = lgb.train(params, train_data, valid_sets=[test_data], num_boost_round=200, early_stopping_rounds=10)

# Predecir en el conjunto de prueba
predictions = model.predict(X_test, num_iteration=model.best_iteration)
predictions = [1 if pred > 0.5 else 0 for pred in predictions]  # Convertir probabilidades en clases

# Evaluar la precisión
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 from sklearn.metrics import accuracy_score
#       4 # Crear los datos de LightGBM
# ----> 5 train_data = lgb.Dataset(X_train, label=y_train)
#       6 test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)
#       8 # Configuración del modelo LightGBM
#
# NameError: name 'X_train' is not defined
